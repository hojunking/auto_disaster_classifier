# %%
from torch import nn
from torchsummary import summary
from torchvision import models
import timm

# %%
class ForcepImgClassifier(nn.Module):
    def __init__(self, model_arch, n_class=2, pretrained=False):
        super(ForcepImgClassifier, self).__init__()
        
        self.model = timm.create_model(model_arch, pretrained=pretrained, num_classes=n_class)
        #self.model = models.resnet18(pretrained = pretrained)
        # n_features = self.model.fc.in_features
        # self.model.fc = nn.Linear(n_features, n_class)
        
    def freezing(self, freeze=False):
        if freeze:
            cnt = 0
            for name, param in model.named_parameters():
                if 'classif' in name:
                    pass
                elif 'fc' in name:
                    pass
                else :
                    param.requires_grad = False
#         try :
#             n_features = self.model.classifier.in_features
#             self.model.classifier = nn.Linear(n_features, n_class)
#             print(f'class{n_features}')
#         except :
            
#             try : 
                
#                 print(f'dense : {n_features}')
#             except :
#                 try:
#                     n_features = self.model.head.fc.in_channels
#                     self.model.head.fc = nn.Conv2d(n_features,n_class,kernel_size=(1, 1), stride=(1, 1))
#                     print(f'class{n_features}')
#                 except:
#                     n_features = self.model.head.in_features
#                     self.model.head = nn.Linear(n_features, n_class)
#                     print(f'class{n_features}')
            
    def forward(self, x):
        x = self.model(x)
        return x

# %%
model = ForcepImgClassifier('inception_resnet_v2', 2, pretrained=True).to('cuda')
model.freezing(freeze = True)

# %%
#model = timm.create_model('efficientnet_b2', pretrained=True)

# %%
#model.classifier
# Out:
# Linear(in_features=1408, out_features=1000, bias=True)

# %%
for n, p in model.named_parameters():
    if '_fc' not in n:
        p.requires_grad = False

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name)
# Out:
# model.classif.weight
# model.classif.bias

# %%
for name, param in model.named_parameters():
    print(name, param.requires_grad)
# Out:
# model.conv2d_1a.conv.weight False
# model.conv2d_1a.bn.weight False
# model.conv2d_1a.bn.bias False
# model.conv2d_2a.conv.weight False
# model.conv2d_2a.bn.weight False
# model.conv2d_2a.bn.bias False
# model.conv2d_2b.conv.weight False
# model.conv2d_2b.bn.weight False
# model.conv2d_2b.bn.bias False
# model.conv2d_3b.conv.weight False
# model.conv2d_3b.bn.weight False
# model.conv2d_3b.bn.bias False
# model.conv2d_4a.conv.weight False
# model.conv2d_4a.bn.weight False
# model.conv2d_4a.bn.bias False
# model.mixed_5b.branch0.conv.weight False
# model.mixed_5b.branch0.bn.weight False
# model.mixed_5b.branch0.bn.bias False
# model.mixed_5b.branch1.0.conv.weight False
# model.mixed_5b.branch1.0.bn.weight False
# model.mixed_5b.branch1.0.bn.bias False
# model.mixed_5b.branch1.1.conv.weight False
# model.mixed_5b.branch1.1.bn.weight False
# model.mixed_5b.branch1.1.bn.bias False
# model.mixed_5b.branch2.0.conv.weight False
# model.mixed_5b.branch2.0.bn.weight False
# ...

# %%
summary(model , input_size=(3, 260, 260))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 130, 130]             864
#           Identity-2         [-1, 32, 130, 130]               0
#               SiLU-3         [-1, 32, 130, 130]               0
#     BatchNormAct2d-4         [-1, 32, 130, 130]              64
#             Conv2d-5         [-1, 32, 130, 130]             288
#           Identity-6         [-1, 32, 130, 130]               0
#               SiLU-7         [-1, 32, 130, 130]               0
#     BatchNormAct2d-8         [-1, 32, 130, 130]              64
#             Conv2d-9              [-1, 8, 1, 1]             264
#              SiLU-10              [-1, 8, 1, 1]               0
#            Conv2d-11             [-1, 32, 1, 1]             288
#           Sigmoid-12             [-1, 32, 1, 1]               0
#     SqueezeExcite-13         [-1, 32, 130, 130]               0
# ...

# %%
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
